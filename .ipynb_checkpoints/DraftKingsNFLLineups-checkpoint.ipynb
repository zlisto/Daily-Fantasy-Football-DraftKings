# %% [markdown]
# # Calculate NFL Lineups for DraftKings Contests

# %%
import pulp
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from data_cleaning import *

# %% [markdown]
# # Lineup Parameters
#
# `nlineups` = number of lineups to enter
#
# `noverlap` = maximum number of players that can be shared between a pair of lineups
#
# `max_use` = maximum number of lineups a player can be in
#
# `qb_stack`  = how many wide receivers to stack with a quarterback in a lineup

# %%
nlineups = 150
noverlap = 4
max_use = 30
qb_stack = 1

# %% [markdown]
# # Load Data

# %%
path = '2023-11-12'
fname_salary = f"{path}/DKSalaries.csv"  #file with DraftKings salaries
fname_entries = f"{path}/DKEntries.csv"  #file where your lineup entries will be saved

fname_proj_offense = f"{path}/DFN NFL Offense DK 11_12.csv"  #file with Daily Fantasy Nerd offense projections
fname_proj_defense = f"{path}/DFN NFL Defense DK 11_12.csv"  #file with Daily Fantasy Nerd defense projections
fname_lineups = f"{path}/lineups.csv"

df = load_data(fname_salary, fname_proj_offense, fname_proj_defense)

df = df.reset_index(drop = True)

print(f"{nlineups} lineups\nMaximum {noverlap} player overlap between lineups\nMaximum {max_use} lineups per player")
print(f"{qb_stack} QB-WR stack")
print(f"Lineups saved to {fname_lineups}")
# Out:
# 150 lineups
# Maximum 4 player overlap between lineups
# Maximum 30 lineups per player
# 1 QB-WR stack
# Lineups saved to 2023-11-12/lineups.csv

# %% [markdown]
# # Create Data Matrices for Optimization

# %%
#Games matrix
ngames = len(df['Game'].unique())
nteams = len(df['Team'].unique())
nopp = len(df['Opp'].unique())
nplayers = len(df)
assert nteams == nopp
print(f"{ngames} games between {nteams} teams, {nplayers} players")

teams_dict = {}
for cnt, team in enumerate(df['Team'].unique()):
    teams_dict[team] = cnt
opps_dict = {}
for cnt, team in enumerate(df['Opp'].unique()):
    opps_dict[team] = cnt
games_dict = {}   
for cnt, game in enumerate(df['Game'].unique()):
    games_dict[game] = cnt
    
Games, Opps, Teams = np.zeros((nplayers, ngames)), np.zeros((nplayers, nteams)),np.zeros((nplayers, nteams))
RB, WR, QB, TE, DST  = np.zeros(nplayers),np.zeros(nplayers), np.zeros(nplayers), np.zeros(nplayers), np.zeros(nplayers)
Salary, Proj = np.zeros(nplayers), np.zeros(nplayers)

for index,row in df.iterrows():
    RB[index] = int(row.Pos=='RB')
    WR[index] = int(row.Pos=='WR')
    QB[index] = int(row.Pos=='QB')
    TE[index] = int(row.Pos=='TE')
    DST[index] = int(row.Pos=='DST')
    Salary[index] = row.Salary
    Proj[index] = row['Proj FP']
    ind_game = games_dict[row.Game]
    ind_opp =  teams_dict[row.Opp]
    ind_team = teams_dict[row.Team]
    
    Games[index,ind_game] =1 
    Teams[index,ind_team] =1 
    Opps[index,ind_opp] =1
# Out:
# 10 games between 20 teams, 285 players

# %% [markdown]
# # Calculate Lineups

# %%
# %%time
X = np.zeros((nplayers, nlineups))

for lineup in range(nlineups):
    prob = pulp.LpProblem(f"DK_Lineup_{lineup}", pulp.LpMaximize)

    # Player variables
    xplayer = [pulp.LpVariable(f'player_{i:03}',cat="Binary") for i in range(nplayers)]
    #game variables
    xgame = [pulp.LpVariable(f'game_{i:03}',cat="Binary") for i in range(ngames)]
    #team variables
    xteam = [pulp.LpVariable(f'team_{i:03}',cat="Binary") for i in range(nteams)]
    #qb-receiver stack variables
    xqb_rec = [pulp.LpVariable(f'qb_rec_{i:03}', cat="Binary") for i in range(nteams)]
    
    # Define the objective function: Proj FP * x
    objective = pulp.lpSum([Proj[i] * xplayer[i] for i in range(nplayers)])
    prob += objective

    #Define Position constraints: Pos* x= pi
    prob += (pulp.lpSum([RB[i] * xplayer[i] for i in range(nplayers)]) >= 2, "RB_lower")
    prob += (pulp.lpSum([RB[i] * xplayer[i] for i in range(nplayers)]) <= 2, "RB_upper")
    prob += (pulp.lpSum([WR[i] * xplayer[i] for i in range(nplayers)]) >= 4, "WR_LOWER")    
    prob += (pulp.lpSum([WR[i] * xplayer[i] for i in range(nplayers)]) <= 4, "WR_UPPER")   
    prob += (pulp.lpSum([TE[i] * xplayer[i] for i in range(nplayers)]) >= 1, "TE_LOWER")    
    prob += (pulp.lpSum([TE[i] * xplayer[i] for i in range(nplayers)]) <= 1, "TE_UPPER")       
    prob += (pulp.lpSum([QB[i] * xplayer[i] for i in range(nplayers)]) == 1, "QB")
    prob += (pulp.lpSum([DST[i] * xplayer[i] for i in range(nplayers)]) == 1, "DST")
    
    #Define total players constraint: 1*x = 9
    prob += (pulp.lpSum([xplayer[i] for i in range(nplayers)]) == 9, "9_players")

    #Define salary constriant: Salary*x <=50000
    prob += (pulp.lpSum([Salary[i] * xplayer[i] for i in range(nplayers)]) <= 50000, "Salary")
    
    # 2 different games constraints
    for j in range(ngames):
        prob += (pulp.lpSum([Games[i,j] * xplayer[i] for i in range(nplayers)]) >= xgame[j], f"Game_{j}")
    prob += (pulp.lpSum([xgame[i] for i in range(ngames)]) >= 2, f"Games")
    
   # 2 different teams constraints
    for j in range(nteams):
        prob += (pulp.lpSum([Teams[i,j] * xplayer[i] for i in range(nplayers)]) >= xteam[j], f"Team_{j}")
    prob += (pulp.lpSum([xteam[i] for i in range(nteams)]) >= 2, f"Teams")  
     
    #QB - WR Stack - Put 1 QB with 2 WR 
    for j in range(nteams):
        prob += (pulp.lpSum([((8-qb_stack)*QB[i] + WR[i])*Teams[i,j] * xplayer[i] for i in range(nplayers)]) >= 8*xqb_rec[j]
                 , f"qb_rec_stack_{j}")
    prob += (pulp.lpSum([xqb_rec[i] for i in range(nteams)]) >= 1, f"qb_rec_stacks")
       
    #NO DST VS Offense  constraint
    for j in range(nteams):
        prob += (pulp.lpSum([((1-DST[i])*Teams[i,j] + 8*DST[i]*Opps[i,j]) * xplayer[i] for i in range(nplayers)]) <=8, 
                 f"No_DST_Offense_{j}")
    
    #No QB and RB on same team, no RB and RB on same team
    for j in range(nteams):
        prob += (pulp.lpSum([(QB[i] + RB[i])*Teams[i,j] * xplayer[i] for i in range(nplayers)]) <=1, 
                 f"No_DST_Offense_Team_{j}")
    
    #No WR/TE and RB on same team
    for j in range(nteams):
        prob += (pulp.lpSum([(2*RB[i] + WR[i] + TE[i])*Teams[i,j] * xplayer[i] for i in range(nplayers)]) <=2, 
                 f"No_RB_Rec_Team_{j}")
    
    #CAP PlAYER USAGE IN LINEUPS    
    if lineup >=1:        
        for j in range(nplayers):
            z = X[j,:]
            prob += (pulp.lpSum([z[i]  for i in range(lineup)])* xplayer[j] <= max_use, f"Max_use_player_{j}")
    
    #Overlap constraints: X[:,j]*x <=noverlap
    if lineup >=1:        
        for j in range(lineup):
            #print(f"\tLineup {lineup}:{j} overlap constraint")
            z = X[:,j]
            prob += (pulp.lpSum([z[i] * xplayer[i] for i in range(nplayers)]) <= noverlap, f"Overlap_{lineup}_{j}")
    
    ########################################################################
    # Solve the problem
    prob.solve()
    new_lineup = np.array( [v.varValue for v in prob.variables() if 'player_' in str(v)])
  
    X[:,lineup] = new_lineup 
    lineup_salary = df.iloc[new_lineup==1]['Salary'].sum()

    # Print the optimal objective value
    print(f"Lineup {lineup+1}: {pulp.LpStatus[prob.status]}: Objective ={pulp.value(prob.objective):.2f}, Salary =${lineup_salary:,}")
X=X.T
print(f"Saving lineups to {fname_lineups}")
df_lineups = write_lineups(X, df, fname_lineups)
df_lineups
# Out:
# Lineup 1: Optimal: Objective =134.70, Salary =$50,000
# Lineup 2: Optimal: Objective =134.40, Salary =$50,000
# Lineup 3: Optimal: Objective =133.90, Salary =$49,900
# Lineup 4: Optimal: Objective =133.00, Salary =$50,000
# Lineup 5: Optimal: Objective =132.70, Salary =$49,900
# Lineup 6: Optimal: Objective =132.20, Salary =$49,900
# Lineup 7: Optimal: Objective =132.10, Salary =$50,000
# Lineup 8: Optimal: Objective =131.80, Salary =$49,900
# Lineup 9: Optimal: Objective =131.80, Salary =$49,900
# Lineup 10: Optimal: Objective =131.70, Salary =$50,000
# Lineup 11: Optimal: Objective =131.60, Salary =$50,000
# Lineup 12: Optimal: Objective =131.50, Salary =$49,900
# Lineup 13: Optimal: Objective =131.50, Salary =$50,000
# Lineup 14: Optimal: Objective =131.50, Salary =$50,000
# Lineup 15: Optimal: Objective =131.40, Salary =$50,000
# Lineup 16: Optimal: Objective =131.30, Salary =$49,900
# Lineup 17: Optimal: Objective =131.20, Salary =$50,000
# Lineup 18: Optimal: Objective =131.10, Salary =$50,000
# Lineup 19: Optimal: Objective =131.10, Salary =$50,000
# Lineup 20: Optimal: Objective =131.10, Salary =$49,900
# Lineup 21: Optimal: Objective =131.00, Salary =$50,000
# Lineup 22: Optimal: Objective =130.80, Salary =$49,600
# Lineup 23: Optimal: Objective =130.80, Salary =$50,000
# Lineup 24: Optimal: Objective =130.80, Salary =$49,900
# Lineup 25: Optimal: Objective =130.80, Salary =$50,000
# Lineup 26: Optimal: Objective =130.70, Salary =$50,000
# Lineup 27: Optimal: Objective =130.70, Salary =$50,000
# Lineup 28: Optimal: Objective =130.60, Salary =$50,000
# Lineup 29: Optimal: Objective =130.60, Salary =$50,000
# Lineup 30: Optimal: Objective =130.60, Salary =$50,000
# Lineup 31: Optimal: Objective =130.60, Salary =$50,000
# Lineup 32: Optimal: Objective =130.50, Salary =$49,900
# Lineup 33: Optimal: Objective =130.40, Salary =$50,000
# Lineup 34: Optimal: Objective =130.40, Salary =$49,800
# Lineup 35: Optimal: Objective =130.30, Salary =$49,900
# Lineup 36: Optimal: Objective =130.30, Salary =$50,000
# Lineup 37: Optimal: Objective =130.30, Salary =$50,000
# Lineup 38: Optimal: Objective =130.30, Salary =$50,000
# Lineup 39: Optimal: Objective =130.20, Salary =$50,000
# Lineup 40: Optimal: Objective =130.20, Salary =$49,800
# Lineup 41: Optimal: Objective =130.10, Salary =$50,000
# Lineup 42: Optimal: Objective =130.10, Salary =$50,000
# Lineup 43: Optimal: Objective =130.00, Salary =$50,000
# Lineup 44: Optimal: Objective =130.00, Salary =$50,000
# Lineup 45: Optimal: Objective =129.90, Salary =$50,000
# Lineup 46: Optimal: Objective =129.80, Salary =$50,000
# Lineup 47: Optimal: Objective =129.80, Salary =$49,900
# Lineup 48: Optimal: Objective =129.80, Salary =$50,000
# Lineup 49: Optimal: Objective =129.80, Salary =$49,900
# Lineup 50: Optimal: Objective =129.70, Salary =$50,000
# Lineup 51: Optimal: Objective =129.70, Salary =$50,000
# Lineup 52: Optimal: Objective =129.60, Salary =$50,000
# Lineup 53: Optimal: Objective =129.60, Salary =$50,000
# Lineup 54: Optimal: Objective =129.60, Salary =$50,000
# Lineup 55: Optimal: Objective =129.60, Salary =$50,000
# Lineup 56: Optimal: Objective =129.50, Salary =$50,000
# Lineup 57: Optimal: Objective =129.40, Salary =$49,800
# Lineup 58: Optimal: Objective =129.40, Salary =$49,900
# Lineup 59: Optimal: Objective =129.30, Salary =$49,900
# Lineup 60: Optimal: Objective =129.30, Salary =$50,000
# Lineup 61: Optimal: Objective =129.10, Salary =$50,000
# Lineup 62: Optimal: Objective =128.70, Salary =$49,900
# Lineup 63: Optimal: Objective =128.60, Salary =$49,900
# Lineup 64: Optimal: Objective =128.60, Salary =$50,000
# Lineup 65: Optimal: Objective =128.40, Salary =$49,900
# Lineup 66: Optimal: Objective =128.40, Salary =$50,000
# Lineup 67: Optimal: Objective =128.40, Salary =$50,000
# Lineup 68: Optimal: Objective =128.20, Salary =$50,000
# Lineup 69: Optimal: Objective =128.20, Salary =$49,800
# Lineup 70: Optimal: Objective =128.10, Salary =$50,000
# Lineup 71: Optimal: Objective =127.80, Salary =$50,000
# Lineup 72: Optimal: Objective =127.70, Salary =$50,000
# Lineup 73: Optimal: Objective =127.40, Salary =$49,900
# Lineup 74: Optimal: Objective =127.30, Salary =$50,000
# Lineup 75: Optimal: Objective =127.20, Salary =$50,000
# Lineup 76: Optimal: Objective =127.20, Salary =$49,800
# Lineup 77: Optimal: Objective =127.10, Salary =$49,900
# Lineup 78: Optimal: Objective =127.10, Salary =$49,900
# Lineup 79: Optimal: Objective =127.10, Salary =$50,000
# Lineup 80: Optimal: Objective =127.00, Salary =$49,900
# Lineup 81: Optimal: Objective =127.00, Salary =$50,000
# Lineup 82: Optimal: Objective =127.00, Salary =$49,900
# Lineup 83: Optimal: Objective =126.80, Salary =$50,000
# Lineup 84: Optimal: Objective =126.60, Salary =$50,000
# Lineup 85: Optimal: Objective =126.40, Salary =$49,900
# Lineup 86: Optimal: Objective =126.20, Salary =$49,900
# Lineup 87: Optimal: Objective =126.20, Salary =$50,000
# Lineup 88: Optimal: Objective =126.10, Salary =$49,900
# Lineup 89: Optimal: Objective =126.10, Salary =$50,000
# Lineup 90: Optimal: Objective =125.80, Salary =$50,000
# Lineup 91: Optimal: Objective =125.80, Salary =$50,000
# Lineup 92: Optimal: Objective =125.60, Salary =$50,000
# Lineup 93: Optimal: Objective =125.60, Salary =$50,000
# Lineup 94: Optimal: Objective =125.40, Salary =$50,000
# Lineup 95: Optimal: Objective =125.30, Salary =$50,000
# Lineup 96: Optimal: Objective =125.20, Salary =$50,000
# Lineup 97: Optimal: Objective =125.20, Salary =$49,900
# Lineup 98: Optimal: Objective =125.10, Salary =$49,900
# Lineup 99: Optimal: Objective =124.90, Salary =$50,000
# Lineup 100: Optimal: Objective =124.80, Salary =$50,000
# Lineup 101: Optimal: Objective =124.70, Salary =$50,000
# Lineup 102: Optimal: Objective =124.60, Salary =$49,900
# Lineup 103: Optimal: Objective =124.50, Salary =$50,000
# Lineup 104: Optimal: Objective =124.30, Salary =$50,000
# Lineup 105: Optimal: Objective =124.10, Salary =$49,900
# Lineup 106: Optimal: Objective =123.40, Salary =$49,900
# Lineup 107: Optimal: Objective =123.40, Salary =$50,000
# Lineup 108: Optimal: Objective =123.30, Salary =$50,000
# Lineup 109: Optimal: Objective =123.20, Salary =$50,000
# Lineup 110: Optimal: Objective =123.00, Salary =$49,800
# Lineup 111: Optimal: Objective =123.00, Salary =$49,900
# Lineup 112: Optimal: Objective =122.90, Salary =$49,800
# Lineup 113: Optimal: Objective =122.90, Salary =$50,000
# Lineup 114: Optimal: Objective =122.80, Salary =$50,000
# Lineup 115: Optimal: Objective =122.60, Salary =$50,000
# Lineup 116: Optimal: Objective =122.60, Salary =$50,000
# Lineup 117: Optimal: Objective =122.60, Salary =$50,000
# Lineup 118: Optimal: Objective =122.40, Salary =$50,000
# Lineup 119: Optimal: Objective =122.40, Salary =$50,000
# Lineup 120: Optimal: Objective =122.30, Salary =$50,000
# Lineup 121: Optimal: Objective =122.20, Salary =$50,000
# Lineup 122: Optimal: Objective =122.10, Salary =$49,700
# Lineup 123: Optimal: Objective =122.10, Salary =$49,900
# Lineup 124: Optimal: Objective =121.90, Salary =$50,000
# Lineup 125: Optimal: Objective =121.90, Salary =$50,000
# Lineup 126: Optimal: Objective =121.70, Salary =$50,000
# Lineup 127: Optimal: Objective =121.50, Salary =$50,000
# Lineup 128: Optimal: Objective =121.40, Salary =$50,000
# Lineup 129: Optimal: Objective =121.30, Salary =$50,000
# Lineup 130: Optimal: Objective =121.30, Salary =$50,000
# Lineup 131: Optimal: Objective =120.90, Salary =$50,000
# Lineup 132: Optimal: Objective =120.80, Salary =$49,900
# Lineup 133: Optimal: Objective =120.80, Salary =$50,000
# Lineup 134: Optimal: Objective =120.60, Salary =$50,000
# Lineup 135: Optimal: Objective =120.60, Salary =$50,000
# Lineup 136: Optimal: Objective =120.50, Salary =$50,000
# Lineup 137: Optimal: Objective =120.40, Salary =$50,000
# Lineup 138: Optimal: Objective =120.30, Salary =$50,000
# Lineup 139: Optimal: Objective =120.30, Salary =$50,000
# Lineup 140: Optimal: Objective =120.20, Salary =$50,000
# Lineup 141: Optimal: Objective =120.20, Salary =$49,900
# Lineup 142: Optimal: Objective =120.10, Salary =$50,000
# Lineup 143: Optimal: Objective =120.00, Salary =$50,000
# Lineup 144: Optimal: Objective =119.80, Salary =$49,900
# Lineup 145: Optimal: Objective =119.80, Salary =$50,000
# Lineup 146: Optimal: Objective =119.80, Salary =$50,000
# Lineup 147: Optimal: Objective =119.80, Salary =$50,000
# Lineup 148: Optimal: Objective =119.80, Salary =$50,000
# Lineup 149: Optimal: Objective =119.80, Salary =$50,000
# Lineup 150: Optimal: Objective =119.70, Salary =$50,000
# Saving lineups to 2023-11-12/lineups.csv
# Wall time: 5min 25s
#                              QB                         RB  \
# 0       Dak Prescott (30754548)       Joe Mixon (30754630)
# 1         Joe Burrow (30754547)  Bijan Robinson (30754634)
# 2         Geno Smith (30754553)       Joe Mixon (30754630)
# 3         Jared Goff (30754549)       Joe Mixon (30754630)
# 4         Geno Smith (30754553)       Joe Mixon (30754630)
# ..                          ...                        ...
# 145       Sam Howell (30754552)    James Conner (30754636)
# 146   Baker Mayfield (30754562)     Aaron Jones (30754628)
# 147     Dak Prescott (30754548)   Austin Ekeler (30754610)
# 148      Brock Purdy (30754555)   Austin Ekeler (30754610)
# 149  Taylor Heinicke (30754561)    James Conner (30754636)
#
#                               RB.1                            WR  \
# 0         Rachaad White (30754638)        CeeDee Lamb (30754852)
# 1         Rachaad White (30754638)  Amon-Ra St. Brown (30754854)
# 2          Najee Harris (30754652)  Amon-Ra St. Brown (30754854)
# 3        Bijan Robinson (30754634)  Amon-Ra St. Brown (30754854)
# 4         Rachaad White (30754638)  Amon-Ra St. Brown (30754854)
# ..                             ...                           ...
# 145  Alexander Mattison (30754640)       Keenan Allen (30754848)
# 146        James Conner (30754636)      Ja'Marr Chase (30754850)
# 147        James Conner (30754636)        Chris Olave (30754868)
# 148         Aaron Jones (30754628)      Brandon Aiyuk (30754858)
# 149         Jerome Ford (30754644)       Keenan Allen (30754848)
#
#                            WR.1                       WR.2  \
# 0    DeAndre Hopkins (30754876)  Marquise Brown (30754896)
# 1    Diontae Johnson (30754892)  Marquise Brown (30754896)
# 2      Tyler Lockett (30754874)       Tank Dell (30754890)
# 3    DeAndre Hopkins (30754876)   Calvin Ridley (30754886)
# 4    DeAndre Hopkins (30754876)  Marquise Brown (30754896)
# ..                          ...                        ...
# 145     Drake London (30754888)    Jahan Dotson (30754900)
# 146      Chris Olave (30754868)  Jordan Addison (30754880)
# 147   Jordan Addison (30754880)    Drake London (30754888)
# 148      Chris Olave (30754868)    Robert Woods (30754918)
# 149   Jordan Addison (30754880)    Drake London (30754888)
#
#                             TE                           FLEX  \
# 0      Trey McBride (30755246)          Noah Brown (30754932)
# 1      Trey McBride (30755246)          Tyler Boyd (30754904)
# 2      Trey McBride (30755246)      Marquise Brown (30754896)
# 3      Trey McBride (30755246)      Marquise Brown (30754896)
# 4       Evan Engram (30755232)  Jaxon Smith-Njigba (30754916)
# ..                         ...                            ...
# 145  Dalton Schultz (30755228)      Michael Thomas (30754906)
# 146  Dalton Schultz (30755228)         Trey Palmer (30754966)
# 147    Chig Okonkwo (30755254)       Brandin Cooks (30754910)
# 148  Dalton Schultz (30755228)      Michael Wilson (30754944)
# 149     Sam LaPorta (30755222)        Jahan Dotson (30754900)
#
#                         DST
# 0       Cowboys  (30755438)
# 1       Cowboys  (30755438)
# 2       Cowboys  (30755438)
# 3       Bengals  (30755452)
# 4        Ravens  (30755440)
# ..                      ...
# 145      Ravens  (30755440)
# 146  Buccaneers  (30755445)
# 147      Ravens  (30755440)
# 148  Buccaneers  (30755445)
# 149     Bengals  (30755452)
#
# [150 rows x 9 columns]

# %% [markdown]
# ## Update Entries
#
# Use the `update_entries` function to directly update the DraftKings DKEntries file with your new lineups.  Do this if you already calculated your lineups.  I wrote this to save an extra copy and paste step from the lineups file to the entries file.

# %%
df_entries = update_entries(fname_entries, df_lineups)

# %% [markdown]
# ## Teams in Lineup
#
# This creates a dataframe `df_lineups_team` that lets you see which positions are stacked with the quarterback.

# %%
# Create a mapping from "Name + ID" to "Team"
name_to_team = df.set_index('Name + ID')['Team'].to_dict()

# Replace player names in df_lineups with their teams
df_lineups_team = df_lineups.replace(name_to_team)

# %%
df_lineups_team.head(10)
# Out:
#     QB   RB RB.1   WR WR.1 WR.2   TE FLEX  DST
# 0  DAL  CIN   TB  DAL  TEN  ARI  ARI  HOU  DAL
# 1  CIN  ATL   TB  DET  PIT  ARI  ARI  CIN  DAL
# 2  SEA  CIN  PIT  DET  SEA  HOU  ARI  ARI  DAL
# 3  DET  CIN  ATL  DET  TEN  JAX  ARI  ARI  CIN
# 4  SEA  CIN   TB  DET  TEN  ARI  JAX  SEA  BAL
# 5  CIN  LAC  JAX  TEN  HOU  ARI  ARI  CIN  DAL
# 6  WAS  CIN  ATL  DET  WAS  ARI  JAX  HOU  DAL
# 7  DAL  PIT  HOU  DAL  DET  ARI  ARI  CIN   TB
# 8  DET  CIN   TB  DET  HOU  PIT  MIN  ARI  NYG
# 9  CIN  PIT  HOU  DET  TEN  WAS  JAX  CIN  DAL

# %%
plt.figure(figsize = (20,20))
for cnt,pos in enumerate(['QB','DST','TE',
                          "WR","WR.1","WR.2", 
                          'RB','RB.1', 'FLEX',]):
    order = df_lineups[pos].value_counts().index
    plt.subplot(3,3,cnt+1)
    sns.countplot(data = df_lineups, y = pos, order = order)
    plt.grid()
    plt.xlim([0,52])
plt.show()
